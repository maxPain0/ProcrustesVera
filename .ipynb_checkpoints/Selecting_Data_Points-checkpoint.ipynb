# %%
import matplotlib
matplotlib.use('TkAgg')
import numpy as np
import matplotlib.pyplot as plt


# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.set_title('click on points')

import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)

xs = np.random.random(100)*10+20
ys = np.random.random(100)*5+7
zs = np.random.random(100)*15+50
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs,ys,zs)

line, = ax.plot(np.random.rand(1000), 'o', picker=5)  # 5 points tolerance

points = []
n = 5

def onpick(event):
    if len(points) < n:
        thisline = event.artist
        xdata = thisline.get_xdata()
        ydata = thisline.get_ydata()
        zdata = thisline.get_zdata()
        ind = event.ind
        point = tuple(zip(xdata[ind], ydata[ind], zdata[ind]))
        points.append(point)
        print('onpick point:', point)
    else:
        print('already have {} points'.format(len(points)))


fig.canvas.mpl_connect('pick_event', onpick)

plt.show()
# Out:
# <ipython-input-3-5bb3fd1abc4a>:22: MatplotlibDeprecationWarning: Setting the line's pick radius via set_picker is deprecated since 3.3 and will be removed two minor releases later; use set_pickradius instead.
#   line, = ax.plot(np.random.rand(1000), 'o', picker=5)  # 5 points tolerance
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5bb3fd1abc4a> in <module>
#      20 ax.scatter(xs,ys,zs)
#      21
# ---> 22 line, = ax.plot(np.random.rand(1000), 'o', picker=5)  # 5 points tolerance
#      23
#      24 points = []
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1474
#    1475         xs, ys, zs = art3d.juggle_axes(xs, ys, zs, zdir)
# -> 1476         self.auto_scale_xyz(xs, ys, zs, had_data)
#    1477         return lines
#    1478
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)

xs = np.random.random(100)*10+20

ys = np.random.random(100)*5+7

zs = np.random.random(100)*15+50

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

ax.scatter(xs,ys,zs)

plt.show()
